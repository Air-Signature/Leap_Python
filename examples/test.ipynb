# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
# Read data from CSV file
df = pd.read_csv('../Signatures/updated_updated_1.csv')

# %%
df = df[df['target'] != 0]

# Extract x, y, z coordinates
x = df['index_x_coor']
y = df['index_y_coor']
z = df['index_z_coor']


# Create a 3D plot plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y,z, c='r')


# Set labels for each axis
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the 3D plot
plt.show()

# Create 2D projections
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# X-Y projection
axs[0].plot(x, y, c='r', marker='o')
axs[0].set_xlabel('X')
axs[0].set_ylabel('Y')

# X-Z projection
axs[1].plot(x, z, c='g', marker='o')
axs[1].set_xlabel('X')
axs[1].set_ylabel('Z')

# Y-Z projection
axs[2].plot(y, z, c='b', marker='o')
axs[2].set_xlabel('Y')
axs[2].set_ylabel('Z')

# Show the 2D projections
plt.show()

# %%
# Extract x, y, z coordinates
x2 = df['palm_x_coor']
y2 = df['palm_y_coor']
z2 = df['palm_z_coor']


# Create a 3D plot plot
fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d')
ax2.plot(x2, y2,z2, c='r')


# Set labels for each axis
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

# Show the 3D plot
plt.show()

# Create 2D projections
fig2, axs2 = plt.subplots(1, 3, figsize=(15, 5))

# X-Y projection
axs2[0].plot(x2, y2, c='r', marker='o')
axs2[0].set_xlabel('X')
axs2[0].set_ylabel('Y')

# X-Z projection
axs2[1].plot(x2, z2, c='g', marker='o')
axs2[1].set_xlabel('X')
axs2[1].set_ylabel('Z')

# Y-Z projection
axs2[2].plot(y2, z2, c='b', marker='o')
axs2[2].set_xlabel('Y')
axs2[2].set_ylabel('Z')

# Show the 2D projections
plt.show()

# %%
# Extract x, y, z coordinates
x3 = df['index_x_velocity']
y3 = df['index_y_velocity']
z3 = df['index_z_velocity']

# %%
x3.plot()
# Out:
# <Axes: >

# %%
y3.plot()
# Out:
# <Axes: >

# %%
z3.plot()
# Out:
# <Axes: >

# %%
# Extract x, y, z coordinates
px = df['palm_velocity_x']
py = df['palm_velocity_y']
pz = df['palm_velocity_z']

# %%
px.plot()
# Out:
# <Axes: >

# %%
py.plot()
# Out:
# <Axes: >

# %%
pz.plot()
# Out:
# <Axes: >
